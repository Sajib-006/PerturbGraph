# %% [markdown]
# ## Replogle data

# %%
# !python stable_shift_bench_tf_v5.py \
  --h5ad /home/sajibacharjeedip/shared_disk/Perturb/data/K562_essential_normalized_singlecell_01.h5ad \
  --string_links /home/sajibacharjeedip/shared_disk/Perturb/9606.protein.links.v11.5.txt \
  --string_info /home/sajibacharjeedip/shared_disk/Perturb/9606.protein.info.v11.5.txt \
  --dorothea_file /home/sajibacharjeedip/shared_disk/Perturb/data_DoRothEA/TF_target_sources/merged_interactions.txt \
  --go_file /home/sajibacharjeedip/shared_disk/Perturb/go_annotations.tsv \
  --outdir bench_main_baselines_eccb \
  --model_type mlp \
  --graph_type STRING_only \
  --use_bio_features \
  --use_go_features \
  --go_gene_col gene \
  --go_term_col go_id \
  --go_sep $'\t' \
  --go_min_genes_per_term 5 \
  --go_max_genes_per_term 500 \
  --go_svd_dim 64 \
  --node2vec_dim 256 \
  --n2v_walk_length 40 \
  --n2v_num_walks 150 \
  --n2v_window 10 \
  --n2v_p 0.5 \
  --n2v_q 2.0 \
  --seed 42 > stable_shift_bench_tf_v5_mlp.log 2>&1

# %%
# !python stable_shift_bench_tf_v5.py \
  --h5ad /home/sajibacharjeedip/shared_disk/Perturb/data/K562_essential_normalized_singlecell_01.h5ad \
  --string_links /home/sajibacharjeedip/shared_disk/Perturb/9606.protein.links.v11.5.txt \
  --string_info /home/sajibacharjeedip/shared_disk/Perturb/9606.protein.info.v11.5.txt \
  --dorothea_file /home/sajibacharjeedip/shared_disk/Perturb/data_DoRothEA/TF_target_sources/merged_interactions.txt \
  --go_file /home/sajibacharjeedip/shared_disk/Perturb/go_annotations.tsv \
  --outdir bench_main_baselines_eccb \
  --model_type ridge \
  --graph_type STRING_only \
  --use_bio_features \
  --use_go_features \
  --go_gene_col gene \
  --go_term_col go_id \
  --go_sep $'\t' \
  --go_min_genes_per_term 5 \
  --go_max_genes_per_term 500 \
  --go_svd_dim 64 \
  --node2vec_dim 256 \
  --n2v_walk_length 40 \
  --n2v_num_walks 150 \
  --n2v_window 10 \
  --n2v_p 0.5 \
  --n2v_q 2.0 \
  --seed 42 > stable_shift_bench_tf_v5_ridge.log 2>&1

# %%
# !python stable_shift_bench_tf_v5.py \
  --h5ad /home/sajibacharjeedip/shared_disk/Perturb/data/K562_essential_normalized_singlecell_01.h5ad \
  --string_links /home/sajibacharjeedip/shared_disk/Perturb/9606.protein.links.v11.5.txt \
  --string_info /home/sajibacharjeedip/shared_disk/Perturb/9606.protein.info.v11.5.txt \
  --dorothea_file /home/sajibacharjeedip/shared_disk/Perturb/data_DoRothEA/TF_target_sources/merged_interactions.txt \
  --go_file /home/sajibacharjeedip/shared_disk/Perturb/go_annotations.tsv \
  --outdir bench_main_baselines_eccb \
  --model_type knn \
  --graph_type STRING_only \
  --use_bio_features \
  --use_go_features \
  --go_gene_col gene \
  --go_term_col go_id \
  --go_sep $'\t' \
  --go_min_genes_per_term 5 \
  --go_max_genes_per_term 500 \
  --go_svd_dim 64 \
  --node2vec_dim 256 \
  --n2v_walk_length 40 \
  --n2v_num_walks 150 \
  --n2v_window 10 \
  --n2v_p 0.5 \
  --n2v_q 2.0 \
  --seed 42 > stable_shift_bench_tf_v5_knn.log 2>&1

# %%
### Node2vec only
# !python stable_shift_bench_tf_v5.py \
  --h5ad /home/sajibacharjeedip/shared_disk/Perturb/data/K562_essential_normalized_singlecell_01.h5ad \
  --string_links /home/sajibacharjeedip/shared_disk/Perturb/9606.protein.links.v11.5.txt \
  --string_info /home/sajibacharjeedip/shared_disk/Perturb/9606.protein.info.v11.5.txt \
  --dorothea_file /home/sajibacharjeedip/shared_disk/Perturb/data_DoRothEA/TF_target_sources/merged_interactions.txt \
  --go_file /home/sajibacharjeedip/shared_disk/Perturb/go_annotations.tsv \
  --outdir eccb/bench_feature_ablation \
  --model_type gcn \
  --graph_type STRING_only \
  --go_gene_col gene \
  --go_term_col go_id \
  --go_sep $'\t' \
  --go_min_genes_per_term 5 \
  --go_max_genes_per_term 500 \
  --go_svd_dim 64 \
  --node2vec_dim 256 \
  --n2v_walk_length 40 \
  --n2v_num_walks 150 \
  --n2v_window 10 \
  --n2v_p 0.5 \
  --n2v_q 2.0 \
  --seed 42 > stable_shift_bench_tf_v5_node2vec.log 2>&1

# %%
### Node2vec + bio features
# !python stable_shift_bench_tf_v5.py \
  --h5ad /home/sajibacharjeedip/shared_disk/Perturb/data/K562_essential_normalized_singlecell_01.h5ad \
  --string_links /home/sajibacharjeedip/shared_disk/Perturb/9606.protein.links.v11.5.txt \
  --string_info /home/sajibacharjeedip/shared_disk/Perturb/9606.protein.info.v11.5.txt \
  --dorothea_file /home/sajibacharjeedip/shared_disk/Perturb/data_DoRothEA/TF_target_sources/merged_interactions.txt \
  --go_file /home/sajibacharjeedip/shared_disk/Perturb/go_annotations.tsv \
  --outdir eccb/bench_feature_ablation \
  --model_type gcn \
  --graph_type STRING_only \
  --go_gene_col gene \
  --go_term_col go_id \
  --go_sep $'\t' \
  --go_min_genes_per_term 5 \
  --go_max_genes_per_term 500 \
  --go_svd_dim 64 \
  --node2vec_dim 256 \
  --n2v_walk_length 40 \
  --n2v_num_walks 150 \
  --n2v_window 10 \
  --use_bio_features \
  --n2v_p 0.5 \
  --n2v_q 2.0 \
  --seed 42 > stable_shift_bench_tf_v5_node2vec_bio.log 2>&1

# %%
### Node2vec + go features
# !python stable_shift_bench_tf_v5.py \
  --h5ad /home/sajibacharjeedip/shared_disk/Perturb/data/K562_essential_normalized_singlecell_01.h5ad \
  --string_links /home/sajibacharjeedip/shared_disk/Perturb/9606.protein.links.v11.5.txt \
  --string_info /home/sajibacharjeedip/shared_disk/Perturb/9606.protein.info.v11.5.txt \
  --dorothea_file /home/sajibacharjeedip/shared_disk/Perturb/data_DoRothEA/TF_target_sources/merged_interactions.txt \
  --go_file /home/sajibacharjeedip/shared_disk/Perturb/go_annotations.tsv \
  --outdir eccb/bench_feature_ablation \
  --model_type gcn \
  --graph_type STRING_only \
  --go_gene_col gene \
  --go_term_col go_id \
  --go_sep $'\t' \
  --go_min_genes_per_term 5 \
  --go_max_genes_per_term 500 \
  --go_svd_dim 64 \
  --node2vec_dim 256 \
  --n2v_walk_length 40 \
  --n2v_num_walks 150 \
  --n2v_window 10 \
  --use_go_features \
  --n2v_p 0.5 \
  --n2v_q 2.0 \
  --seed 42 > stable_shift_bench_tf_v5_node2vec_go.log 2>&1

# %%
### Node2vec + bio + go features
# !python stable_shift_bench_tf_v5.py \
  --h5ad /home/sajibacharjeedip/shared_disk/Perturb/data/K562_essential_normalized_singlecell_01.h5ad \
  --string_links /home/sajibacharjeedip/shared_disk/Perturb/9606.protein.links.v11.5.txt \
  --string_info /home/sajibacharjeedip/shared_disk/Perturb/9606.protein.info.v11.5.txt \
  --dorothea_file /home/sajibacharjeedip/shared_disk/Perturb/data_DoRothEA/TF_target_sources/merged_interactions.txt \
  --go_file /home/sajibacharjeedip/shared_disk/Perturb/go_annotations.tsv \
  --outdir eccb/bench_feature_ablation \
  --model_type gcn \
  --graph_type STRING_only \
  --go_gene_col gene \
  --go_term_col go_id \
  --go_sep $'\t' \
  --go_min_genes_per_term 5 \
  --go_max_genes_per_term 500 \
  --go_svd_dim 64 \
  --node2vec_dim 256 \
  --n2v_walk_length 40 \
  --n2v_num_walks 150 \
  --n2v_window 10 \
  --use_go_features \
  --use_bio_features \
  --n2v_p 0.5 \
  --n2v_q 2.0 \
  --seed 42 > stable_shift_bench_tf_v5_node2vec_bio_go.log 2>&1

# %%
# Qualitative analysis on best node2vec model
# !python qualitative_analysis_stableshift_eccb.py \
  --h5ad /home/sajibacharjeedip/shared_disk/Perturb/data/K562_essential_normalized_singlecell_01.h5ad \
  --string_links /home/sajibacharjeedip/shared_disk/Perturb/9606.protein.links.v11.5.txt \
  --string_info /home/sajibacharjeedip/shared_disk/Perturb/9606.protein.info.v11.5.txt \
  --go_file /home/sajibacharjeedip/shared_disk/Perturb/go_annotations.tsv \
  --outdir eccb/qualitative_results_k562_best \
  --node2vec_dim 256 \
  --n2v_walk_length 40 \
  --n2v_num_walks 150 \
  --n2v_window 10 \
  --n2v_p 0.5 \
  --n2v_q 2.0 \
  --seed 42 > eccb/qualitative_analysis.log 2>&1

# %%
# !python qualitative_analysis_stableshift_eccb.py \
  --h5ad /home/sajibacharjeedip/shared_disk/Perturb/data/K562_essential_normalized_singlecell_01.h5ad \
  --string_links /home/sajibacharjeedip/shared_disk/Perturb/9606.protein.links.v11.5.txt \
  --string_info /home/sajibacharjeedip/shared_disk/Perturb/9606.protein.info.v11.5.txt \
  --go_file /home/sajibacharjeedip/shared_disk/Perturb/go_annotations.tsv \
  --gmt_file /home/sajibacharjeedip/shared_disk/Perturb/pathway_data/ReactomePathways.gmt \
  --outdir eccb/qualitative_results_k562_best_v2 \
  --node2vec_dim 256 \
  --n2v_walk_length 40 \
  --n2v_num_walks 150 \
  --n2v_window 10 \
  --n2v_p 0.5 \
  --n2v_q 2.0 \
  --seed 42 > eccb/qualitative_analysis_v2.log 2>&1

# %% [markdown]
# ### Run all benchmarks

# %%
# !bash run_all_benchmark_eccb.sh > run_all_benchmarks_eccb.log 2>&1

# %% [markdown]
# ## Norman Data

# %%
# !python inspect_norman_h5ad.py \
  --h5ad /home/sajibacharjeedip/shared_disk/Perturb/data_norman/norman_2019_adata.h5ad \
  --out_prefix norman_2019 > eccb/norman_2019_inspect.txt

# %%
# !python prepare_norman_for_benchmark.py
# Out:
# Loading dataset...
# AnnData object with n_obs × n_vars = 27658 × 2000
#     obs: 'guide_identity', 'read_count', 'UMI_count', 'coverage', 'gemgroup', 'good_coverage', 'number_of_cells', 'guide_merged', 'gene_program'
#     var: 'gene_id', 'gene_name', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm'
#     uns: 'hvg', 'log1p'
#     layers: 'count'
# Cells after removing combos: 15216
# Remaining perturbations: 18
# Saved: data_norman/norman_single_gene_perturbseq.h5ad

# %%
import scanpy as sc

adata = sc.read_h5ad("data_norman/norman_single_gene_perturbseq.h5ad")

print("cells:", adata.n_obs)
print("genes:", adata.n_vars)
print("perturbations:", adata.obs["gene"].nunique())

print(adata.obs["gene"].value_counts().head())
# Out:
# cells: 15216
# genes: 2000
# perturbations: 18
# gene
# control    7275
# KLF1       1629
# CEBPE      1009
# MAPK1       648
# ETS2        641
# Name: count, dtype: int64

# %%
import scanpy as sc
adata = sc.read_h5ad("/home/sajibacharjeedip/shared_disk/Perturb/data_norman/norman_single_gene_perturbseq.h5ad")
print("cells:", adata.n_obs)
print("genes:", adata.n_vars)
print("perturbations:", adata.obs["gene"].nunique())
print(adata.obs["gene"].value_counts().head(30))
# Out:
# cells: 15216
# genes: 2000
# perturbations: 18
# gene
# control    7275
# KLF1       1629
# CEBPE      1009
# MAPK1       648
# ETS2        641
# SPI1        488
# CEBPB       402
# FOXA3       397
# CEBPA       387
# PTPN1       335
# HOXC13      327
# ATL1        301
# CDKN1A      274
# CDKN1B      263
# MIDN        246
# HOXA13      222
# TP73        208
# CDKN1C      164
# Name: count, dtype: int64

# %%
# !python stable_shift_bench_tf_v5.py \
  --h5ad data_norman/norman_single_gene_perturbseq.h5ad \
  --string_links /home/sajibacharjeedip/shared_disk/Perturb/9606.protein.links.v11.5.txt \
  --string_info /home/sajibacharjeedip/shared_disk/Perturb/9606.protein.info.v11.5.txt \
  --go_file /home/sajibacharjeedip/shared_disk/Perturb/go_annotations.tsv \
  --model_type gcn \
  --ctrl_label control \
  --outdir eccb/bench_norman \
  --graph_type STRING_only \
  --node2vec_dim 256 \
  --n2v_p 0.5 \
  --n2v_q 2.0 \
  --seed 42 > eccb/stable_shift_bench_tf_v5_norman.log 2>&1

# %%
# !bash run_all_benchmark_norman.sh > eccb/run_norman_all.log 2>&1
